# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B")
# Out:
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]

# %%
sentences = [
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium."
]

# %%
embeddings = model.encode(sentences)

# %%
embeddings.shape
# Out:
# (3, 1024)

# %%
embeddings
# Out:
# array([[-0.0390625 ,  0.01495361, -0.00482178, ..., -0.00408936,
#          0.01855469,  0.00515747],
#        [-0.00364685,  0.01501465, -0.00601196, ..., -0.01965332,
#         -0.02819824, -0.00238037],
#        [ 0.0300293 , -0.03588867, -0.00262451, ...,  0.01745605,
#          0.0088501 ,  0.00793457]], shape=(3, 1024), dtype=float32)

# %%
similarities = model.similarity(embeddings, embeddings)
print(similarities.shape)
# Out:
# torch.Size([3, 3])

# %%
similarities
# Out:
# tensor([[1.0000, 0.7911, 0.3736],
#         [0.7911, 1.0000, 0.4521],
#         [0.3736, 0.4521, 1.0000]])

# %% [markdown]
# ### Tokenizer

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-Embedding-0.6B")

# %% [markdown]
# #### Tokens por linea

# %%
for t in sentences:
    tokens = tokenizer(t)["input_ids"]
    print(t, "→", len(tokens), "tokens")
# Out:
# The weather is lovely today. → 7 tokens
# It's so sunny outside! → 7 tokens
# He drove to the stadium. → 7 tokens

# %% [markdown]
# #### Total tokens

# %%
total_tokens = sum(len(tokenizer(t)["input_ids"]) for t in sentences)
print("Total tokens:", total_tokens)
# Out:
# Total tokens: 21
